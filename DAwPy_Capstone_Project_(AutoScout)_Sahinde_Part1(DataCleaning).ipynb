# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import plotly 
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import iplot
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

import warnings
warnings.filterwarnings("ignore")

import warnings
# Suppressing a warning 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# Environment settings: 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', 1000)
# Out:
# /Users/sahindedogruer/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
from skimpy import clean_columns

# %%
data = pd.read_json('scout_car.json', lines=True)

# %%
df = data.copy()
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df.drop(columns=["kW","null"],inplace=True)

# %%
from skimpy import clean_columns


columns = df.columns

messy_df = pd.DataFrame(data = [], columns = columns, index = [0])
clean_df = clean_columns(messy_df)
clean_df.columns.tolist()
# Out:
# 41 column names have been cleaned
# ['url',
#  'make_model',
#  'short_description',
#  'body_type',
#  'price',
#  'vat',
#  'km',
#  'registration',
#  'prev_owner',
#  'hp',
#  'type',
#  'previous_owners',
#  'next_inspection',
#  'inspection_new',
#  'warranty',
#  'full_service',
#  'non_smoking_vehicle',
#  'make',
#  'model',
#  'offer_number',
#  'first_registration',
#  'body_color',
#  'paint_type',
#  'body_color_original',
#  'upholstery',
#  'body',
#  'nr_of_doors',
#  'nr_of_seats',
#  'model_code',
#  'gearing_type',
#  'displacement',
#  'cylinders',
#  'weight',
#  'drive_chain',
#  'fuel',
#  'consumption',
#  'co_2_emission',
#  'emission_class',
#  'comfort_&_convenience',
#  'entertainment_&_media',
#  'extras',
#  'safety_&_security',
#  'description',
#  'emission_label',
#  'gears',
#  'country_version',
#  'electricity_consumption',
#  'last_service_date',
#  'other_fuel_types',
#  'availability',
#  'last_timing_belt_service_date',
#  'available_from']

# %%
df = clean_columns(df)
# Out:
# 41 column names have been cleaned

# %%
df.sample(10)
# Out:
#                                                      url      make_model  \
# 4272   https://www.autoscout24.com//offers/audi-a3-li...         Audi A3
# 6399   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 15582  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 6506   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 1912   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 7243   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 12912  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 6651   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 14794  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 14323  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
#
#                                        short_description      body_type  \
# 4272            Limousine 2.0 TDI S line AHK Parkp Sitzh         Sedans
# ...

# %%
df=df.applymap(lambda x: ','.join(map(str,x)) if isinstance(x, list) else x)

# %%
df.head(5)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners   66 kW
# ...

# %%
df =df.applymap(lambda x: x.strip("/\n\n,][ '-.") if isinstance(x, str) else x)

# %%
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners   66 kW
# ...

# %% [markdown]
# ## consumption

# %%
# Divide consumption and assign new Column - 'cons_comb', 'cons_city', 'cons_country'
df['cons_comb'] = df['consumption'].str.extract('(\d+\.\d+|\d+).{0,13}comb')
df['cons_city'] = df['consumption'].str.extract('(\d+\.\d+|\d+).{0,13}city')
df['cons_country'] = df['consumption'].str.extract('(\d+\.\d+|\d+).{0,13}country')

# %% [markdown]
# Another solutions

# %%
#Another way to remove first list paranthesis on the consumption column

# df["comb"]=df["consumption"].str.findall(".+comb\)").transform(lambda x : np.nan if x == [] else x)
# df["city"]=df["consumption"].str.findall("[.+]?,(\d.+city\))").transform(lambda x : np.nan if x == [] else x)
# df["country"]=df["consumption"].str.findall("[.+]?,(\d.+country\))").transform(lambda x : np.nan if x == [] else x)
# df[["comb","city","country"]].isnull().sum()

# %%
# df["consumption"]=df["consumption"].str.replace("\n,","")
# df[["comb","city","country"]]=df["consumption"].str.split(",",expand=True).loc[:,:2].applymap(lambda x : np.nan if x == "[]" or  x == "\n" else x)

# %%
# df[["comb","city","country"]].isnull().sum()

# %%
#Same result at he above by using extract

#df["consumption_comb"] = df.consumption.str.extract(r"(\d*\.\d+|\d+).+\(comb\)")
#df["consumption_city"] = df.consumption.str.extract(r"[.+]?,(\d*\.\d+|\d+).+\(city\)")
#df["consumption_country"] = df.consumption.str.extract(r".+,(\d*\.\d+|\d+).+\(country\)")

# %%
#If you use it, you need to concatenete with 1 non-object column

# df = df.select_dtypes(include="O").apply(lambda x: x.str.replace(",?\n,?",""))
# df.head(10)

# %%
df.sample(10)
# Out:
#                                                      url      make_model  \
# 11853  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 10954  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 2098   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 13564  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 11894  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 5235   https://www.autoscout24.com//offers/audi-a3-sb...         Audi A3
# 14783  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 13265  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 9829   https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 15217  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description      body_type  \
# 11853  ST INNOVATION 2.0 CDTI Automatik Leder LED Matrix  Station wagon
# ...

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique(), end ="\n\n")
    #print('Duplicates     : ', df.duplicated(subset = None, keep = 'first').sum(), end='\n\n')
    print(df[col].value_counts(dropna = False))#.sort_index())
    
    print('#####################')

# %%
for col in df.columns :
    first_look(col)
# Out:
# column name :  url
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15919
#
# https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %% [markdown]
# # Replacing Empty Rows with np.nan

# %%
df.isin(['']).sum()
# Out:
# url                                 0
# make_model                          0
# short_description                   3
# body_type                           0
# price                               0
# vat                                 0
# km                                  0
# registration                     1597
# prev_owner                          0
# hp                                  0
# type                                0
# previous_owners                     0
# next_inspection                     0
# inspection_new                      0
# warranty                         1343
# full_service                     1985
# non_smoking_vehicle              3717
# make                                0
# model                               0
# offer_number                        0
# first_registration                  0
# body_color                          0
# paint_type                          0
# body_color_original                 0
# upholstery                          0
# ...

# %%
df.isin(['[], [],[]']).sum()
# Out:
# url                              0
# make_model                       0
# short_description                0
# body_type                        0
# price                            0
# vat                              0
# km                               0
# registration                     0
# prev_owner                       0
# hp                               0
# type                             0
# previous_owners                  0
# next_inspection                  0
# inspection_new                   0
# warranty                         0
# full_service                     0
# non_smoking_vehicle              0
# make                             0
# model                            0
# offer_number                     0
# first_registration               0
# body_color                       0
# paint_type                       0
# body_color_original              0
# upholstery                       0
# body                             0
# nr_of_doors                      0
# ...

# %%
#Convert empty rows by nan values
df[df.isin([''])] = np.nan

# %%
#Check nan values for each column
df.isna().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   49
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                      1597
# prev_owner                        6828
# hp                                   0
# type                                 2
# previous_owners                   6640
# next_inspection                  12384
# inspection_new                   11987
# warranty                          6763
# full_service                      9689
# non_smoking_vehicle              12459
# make                                 0
# model                                0
# offer_number                      3175
# first_registration                1597
# body_color                         597
# paint_type                        5772
# body_color_original               3759
# ...

# %% [markdown]
# #Check percentage of nan values for each column and drop the columns have 95% and above of nan values

# %%
#First way, using regular division
((df.isna().sum())/(len(df))*100).sort_values(ascending= False)
# Out:
# other_fuel_types                100.000
# last_timing_belt_service_date    99.899
# electricity_consumption          99.139
# available_from                   98.291
# last_service_date                96.445
# availability                     96.011
# non_smoking_vehicle              78.265
# next_inspection                  77.794
# inspection_new                   75.300
# emission_label                   75.218
# model_code                       68.729
# full_service                     60.864
# country_version                  52.346
# weight                           43.809
# drive_chain                      43.081
# prev_owner                       42.892
# warranty                         42.484
# previous_owners                  41.711
# paint_type                       36.259
# cylinders                        35.681
# gears                            29.600
# vat                              28.350
# body_color_original              23.613
# ...

# %%
#deleting nan values if the columns has 95% and above nan values
for col in df.columns:
    if(df[col].isnull().sum() / df.shape[0]*100) >= 95:
        df.drop(col, axis=1, inplace=True)
print(df.shape)
# Out:
# (15919, 49)

# %%
#second way to get null values 95%  and above of nan values 

for col in df.columns:
    if(df[col].isnull().sum() / df.shape[0]*100) >= 95:
        print(col)
        print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
        print('-'*25)

# %% [markdown]
# # Column by Column Data Cleaning

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'cons_comb', 'cons_city', 'cons_country'],
#       dtype='object')

# %%
#url is not active since the links from 2016 that is why drop it directly

df.drop(columns='url', inplace=True)

# %%
df.shape
# Out:
# (15919, 48)

# %% [markdown]
# ## make_model, 'make', 'model'

# %%
df['make_model']
# Out:
# 0               Audi A1
# 1               Audi A1
# 2               Audi A1
# 3               Audi A1
# 4               Audi A1
#               ...
# 15914    Renault Espace
# 15915    Renault Espace
# 15916    Renault Espace
# 15917    Renault Espace
# 15918    Renault Espace
# Name: make_model, Length: 15919, dtype: object

# %%
first_look('make_model')
# Out:
# column name :  make_model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
#
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
# #####################

# %%
df[['make_model', 'make', 'model']]
# Out:
#            make_model     make   model
# 0             Audi A1     Audi      A1
# 1             Audi A1     Audi      A1
# 2             Audi A1     Audi      A1
# 3             Audi A1     Audi      A1
# 4             Audi A1     Audi      A1
# ...               ...      ...     ...
# 15914  Renault Espace  Renault  Espace
# 15915  Renault Espace  Renault  Espace
# 15916  Renault Espace  Renault  Espace
# 15917  Renault Espace  Renault  Espace
# 15918  Renault Espace  Renault  Espace
#
# [15919 rows x 3 columns]

# %%
df[['make_model', 'make', 'model']].isna().sum()
# Out:
# make_model    0
# make          0
# model         0
# dtype: int64

# %%
df[['make_model', 'make', 'model']].nunique()
# Out:
# make_model    9
# make          3
# model         9
# dtype: int64

# %%
df[['make_model', 'make', 'model']].value_counts()
# Out:
# make_model      make     model
# Audi A3         Audi     A3          3097
# Audi A1         Audi     A1          2614
# Opel Insignia   Opel     Insignia    2598
# Opel Astra      Opel     Astra       2526
# Opel Corsa      Opel     Corsa       2219
# Renault Clio    Renault  Clio        1839
# Renault Espace  Renault  Espace       991
# Renault Duster  Renault  Duster        34
# Audi A2         Audi     A2             1
# dtype: int64

# %%
df.drop(columns=['make','model'], inplace=True)

# %% [markdown]
# ## short_description

# %%
df['short_description']
# Out:
# 0              Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1                                           1.8 TFSI sport
# 2        Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3                                  1.4 TDi Design S tronic
# 4        Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
#                                ...
# 15914                Blue dCi 200CV EDC Executive 4Control
# 15915                  TCe 225 EDC GPF LIM Deluxe Pano,RFK
# 15916    Blue dCi 200 EDC Initiale Paris Leder LED Navi...
# 15917    Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...
# 15918          INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX
# Name: short_description, Length: 15919, dtype: object

# %%
first_look('short_description')
# Out:
# column name :  short_description
# --------------------------------
# Per_of_Nulls   :  % 0.31
# Num_of_Nulls   :  49
# Num_of_Uniques :  9971
#
# SPB 1.6 TDI 116 CV S tronic Sport                 64
# None                                              46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 9973, dtype: int64
# #####################

# %%
df.groupby(['make_model'])['short_description'].value_counts(dropna=False)
# Out:
# make_model      short_description
# Audi A1         SPB 30 TFSI S tronic Admired                   34
#                 1.4 TDI Design DKG*Navi*PDC*Alu*SHZ*           27
#                 1.4 TFSI Design*PDC*Sport-S*LM-Felgen*SHZ*     27
#                 1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*    27
#                 1.0 TFSI ultra Sportback                       19
#                                                                ..
# Renault Espace  dCi Energy 160 EDC Initiale Paris               1
#                 dCi Energy 160 EDC Intens                       1
#                 dci 160 Intens Aut. Navi Panorama LED AHK       1
#                 espace INTENS DCI 160 EDC                       1
#                 initiale Paris                                  1
# Name: short_description, Length: 10019, dtype: int64

# %% [markdown]
# # body_type, body

# %%
df['body_type']
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: body_type, Length: 15919, dtype: object

# %%
#There was an error to get strip \\n\n(for this it gives Va instead of Van), /\n\n works and get Van
#data1=data.copy()

# %%
#data1[['body_type']].applymap(lambda x: x.strip("/\n\n][ '-") if isinstance(x, str) else x)

# %%
first_look('body_type')
# Out:
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Num_of_Uniques :  9
#
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# None               60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# #####################

# %%
df[['body_type','body']].value_counts(dropna=False)
# Out:
# body_type      body
# Sedans         Sedans           7903
# Station wagon  Station wagon    3553
# Compact        Compact          3153
# Van            Van               783
# Other          Other             290
# Transporter    Transporter        88
# NaN            NaN                60
# Off-Road       Off-Road           56
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %%
df.groupby(['make_model'])['body_type'].value_counts(dropna=False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1538
#                 Compact          1039
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2598
#                 Station wagon     282
#                 Compact           182
#                 Other              16
#                 Convertible         8
#                 NaN                 7
#                 Coupe               4
# Opel Astra      Station wagon    1211
#                 Sedans           1053
#                 Compact           185
#                 Other              67
#                 NaN                 7
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1230
#                 Sedans            875
#                 Other              87
# ...

# %%
df['body_type']== 'NaN'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15914    False
# 15915    False
# 15916    False
# 15917    False
# 15918    False
# Name: body_type, Length: 15919, dtype: bool

# %%
df[df.body_type.isnull()].isnull().sum()
# Out:
# make_model                0
# short_description         1
# body_type                60
# price                     0
# vat                      40
# km                        0
# registration             12
# prev_owner               51
# hp                        0
# type                      0
# previous_owners          51
# next_inspection          57
# inspection_new           59
# warranty                 55
# full_service             58
# non_smoking_vehicle      58
# offer_number             39
# first_registration       12
# body_color                0
# paint_type               50
# body_color_original      27
# upholstery               52
# body                     60
# nr_of_doors               1
# nr_of_seats              47
# model_code               60
# gearing_type              0
# displacement             23
# cylinders                34
# weight                   52
# drive_chain              58
# fuel                      0
# consumption              19
# ...

# %%
df.drop(columns='body', inplace=True)

# %%
df.shape
# Out:
# (15919, 45)

# %% [markdown]
# # Price

# %%
#Check it later

# %% [markdown]
# # Vat

# %%
df.vat
# Out:
# 0          VAT deductible
# 1        Price negotiable
# 2          VAT deductible
# 3                    None
# 4                    None
#                ...
# 15914      VAT deductible
# 15915      VAT deductible
# 15916      VAT deductible
# 15917      VAT deductible
# 15918      VAT deductible
# Name: vat, Length: 15919, dtype: object

# %%
first_look("vat")
# Out:
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 28.35
# Num_of_Nulls   :  4513
# Num_of_Uniques :  2
#
# VAT deductible      10980
# None                 4513
# Price negotiable      426
# Name: vat, dtype: int64
# #####################

# %%
#Null degerlere missing values larda kontrol et

# %% [markdown]
# # km

# %%
df.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914           km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918           km
# Name: km, Length: 15919, dtype: object

# %%
first_look('km')
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  6690
#
# 10 km        1045
# km           1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
# #####################

# %%
df.km.value_counts()
# Out:
# 10 km        1045
# km           1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64

# %%
df['km'].str.strip('- km').str.replace(',', '').replace(r'', np.nan, regex=True).astype(float)
# Out:
# 0       56013.000
# 1       80000.000
# 2       83450.000
# 3       73000.000
# 4       16200.000
#            ...
# 15914         NaN
# 15915    9900.000
# 15916      15.000
# 15917      10.000
# 15918         NaN
# Name: km, Length: 15919, dtype: float64

# %%
df['km']=df['km'].str.strip('- km').str.replace(',', '').replace(r'', np.nan, regex=True).astype(float)

# %%
first_look('km')
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 6.43
# Num_of_Nulls   :  1024
# Num_of_Uniques :  6689
#
# 10.000       1045
# NaN          1024
# 1.000         367
# 5.000         170
# 50.000        148
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6690, dtype: int64
# #####################

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'offer_number', 'first_registration',
#        'body_color', 'paint_type', 'body_color_original', 'upholstery',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type',
#        'displacement', 'cylinders', 'weight', 'drive_chain', 'fuel',
#        'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'cons_comb', 'cons_city', 'cons_country'],
#       dtype='object')

# %% [markdown]
# # registration

# %%
df.registration
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        NaN
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
first_look('registration')
# Out:
# column name :  registration
# --------------------------------
# Per_of_Nulls   :  % 10.03
# Num_of_Nulls   :  1597
# Num_of_Uniques :  47
#
# NaN        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# ...

# %%
df[['registration','first_registration']].value_counts(dropna=False)
# Out:
# registration  first_registration
# NaN           NaN                   1597
# 03/2018       2018                   695
# 02/2019       2019                   585
# 05/2018       2018                   572
# 03/2019       2019                   543
# 01/2019       2019                   541
# 04/2018       2018                   541
# 02/2018       2018                   539
# 03/2016       2016                   536
# 06/2018       2018                   532
# 04/2016       2016                   532
# 01/2018       2018                   511
# 04/2019       2019                   506
# 02/2016       2016                   472
# 03/2017       2017                   471
# 05/2016       2016                   459
# 06/2016       2016                   452
# 05/2019       2019                   440
# 06/2017       2017                   409
# 05/2017       2017                   404
# 07/2018       2018                   396
# 04/2017       2017                   380
# ...

# %%
df.groupby(['make_model','first_registration', 'registration'])['price'].describe().head(30)
# Out:
#                                              count      mean      std  \
# make_model first_registration registration
# Audi A1    2016               01/2016       45.000 14561.289 1889.312
#                               02/2016      114.000 14458.254 1579.292
#                               03/2016      112.000 14371.036 1785.425
#                               04/2016       97.000 14645.557 1922.469
#                               05/2016       56.000 14832.107 2247.750
#                               06/2016       49.000 13990.469 2192.917
#                               07/2016       35.000 14424.914 2239.819
#                               08/2016       14.000 14096.000 1797.438
#                               09/2016       19.000 14344.474 1973.029
#                               10/2016       38.000 14228.053 1953.543
#                               11/2016       14.000 15131.286 2365.787
#                               12/2016       36.000 14916.528 1188.103
# ...

# %%
df.groupby(['make_model','first_registration'])['price'].describe()
# Out:
#                                     count      mean      std       min  \
# make_model     first_registration
# Audi A1        2016               629.000 14489.769 1889.865  8999.000
#                2017               432.000 16625.734 2194.033 10999.000
#                2018               744.000 18454.753 2608.425 13450.000
#                2019               483.000 24267.431 3128.907 15550.000
# Audi A2        2018                 1.000 28200.000      NaN 28200.000
# Audi A3        2016               818.000 16466.090 2794.818 10950.000
#                2017               675.000 19939.557 4004.252 10550.000
#                2018               777.000 22504.332 5265.565  5555.000
#                2019               519.000 25392.890 3309.710 15500.000
# Opel Astra     2016               519.000 11354.796 2501.799  6000.000
#                2017               587.000 13008.951 2021.046  7800.000
#                2018               727.000 16134.623 1948.987   255.000
# ...

# %%
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat        km registration         prev_owner      hp  \
# 0  15770    VAT deductible 56013.000      01/2016  2 previous owners   66 kW
# 1  14500  Price negotiable 80000.000      03/2017               None  141 kW
# 2  14640    VAT deductible 83450.000      02/2016   1 previous owner   85 kW
# 3  14500              None 73000.000      08/2016   1 previous owner   66 kW
# 4  16790              None 16200.000      05/2016   1 previous owner   66 kW
#
#                                 type previous_owners  \
# ...

# %%
df['first_registration']=df['first_registration'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             15919 non-null  object
#  1   short_description      15870 non-null  object
#  2   body_type              15859 non-null  object
#  3   price                  15919 non-null  int64
#  4   vat                    11406 non-null  object
#  5   km                     14895 non-null  float64
#  6   registration           14322 non-null  object
#  7   prev_owner             9091 non-null   object
#  8   hp                     15919 non-null  object
#  9   type                   15917 non-null  object
#  10  previous_owners        9279 non-null   object
#  11  next_inspection        3535 non-null   object
#  12  inspection_new         3932 non-null   object
#  13  warranty               9156 non-null   object
# ...

# %%
df['registration'] = pd.to_datetime(df.registration)

# %%
df['registration'].dt.to_period('M')
# Out:
# 0        2016-01
# 1        2017-03
# 2        2016-02
# 3        2016-08
# 4        2016-05
#           ...
# 15914        NaT
# 15915    2019-01
# 15916    2019-03
# 15917    2019-06
# 15918    2019-01
# Name: registration, Length: 15919, dtype: period[M]

# %% [markdown]
# ## prev_owner and previous_owners column

# %%
df[['prev_owner', 'previous_owners']]
# Out:
#               prev_owner                                    previous_owners
# 0      2 previous owners                                                  2
# 1                   None                                                NaN
# 2       1 previous owner                                                  1
# 3       1 previous owner                                                  1
# 4       1 previous owner                                                  1
# ...                  ...                                                ...
# 15914               None                                                NaN
# 15915   1 previous owner  1\n,\n,7.4 l/100 km (comb),\n,9.2 l/100 km (ci...
# 15916   1 previous owner                          1\n,\n139 g CO2/km (comb)
# 15917               None                                                NaN
# 15918   1 previous owner                                                  1
#
# [15919 rows x 2 columns]

# %%
first_look('prev_owner')
# Out:
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.89
# Num_of_Nulls   :  6828
# Num_of_Uniques :  4
#
# 1 previous owner     8294
# None                 6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
# #####################

# %%
#Change the data type
df['prev_owner']=df.prev_owner.str.extract(r"(\d)").astype('float')

# %% [markdown]
# ## hp column

# %%
first_look('hp')
# Out:
# column name :  hp
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  81
#
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# kW          88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 76 kW        4
# 65 kW        4
# ...

# %%
df['hp_kW'] = df.hp.str.extract('(\d+)')

# %%
df.hp_kW
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: hp_kW, Length: 15919, dtype: object

# %%
df['hp_kW']=  df['hp_kW'].astype(float)

# %%
#drop hp column
#df.drop(columns="hp",inplace=True)

# %%
df.shape
# Out:
# (15919, 46)

# %% [markdown]
# ## type column

# %%
df.type
# Out:
# 0                        Used,,Diesel (Particulate Filter)
# 1                                           Used,,Gasoline
# 2                        Used,,Diesel (Particulate Filter)
# 3                        Used,,Diesel (Particulate Filter)
# 4                        Used,,Diesel (Particulate Filter)
#                                ...
# 15914                     New,,Diesel (Particulate Filter)
# 15915    Used,,Super 95 / Super Plus 98 (Particulate Fi...
# 15916                               Pre-registered,,Diesel
# 15917                               Pre-registered,,Diesel
# 15918                              Demonstration,,Super 95
# Name: type, Length: 15919, dtype: object

# %%
df[['type', 'fuel']].head()
# Out:
#                                 type                         fuel
# 0  Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 1                     Used,,Gasoline                     Gasoline
# 2  Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 3  Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 4  Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)

# %%
df.type.str.split(',').str[0]
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: type, Length: 15919, dtype: object

# %%
df.type.str.split(',').str[0].isnull().sum()
# Out:
# 2

# %%
df['type'] = df.type.str.split(',').str[0]

# %% [markdown]
# # next_inspection

# %%
df.next_inspection
# Out:
# 0         06/2021\n,\n99 g CO2/km (comb)
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#                       ...
# 15914                                NaN
# 15915    01/2022\n,\n168 g CO2/km (comb)
# 15916                                NaN
# 15917                                NaN
# 15918                                NaN
# Name: next_inspection, Length: 15919, dtype: object

# %%
first_look('next_inspection')
# Out:
# column name :  next_inspection
# --------------------------------
# Per_of_Nulls   :  % 77.79
# Num_of_Nulls   :  12384
# Num_of_Uniques :  1384
#
# NaN                                12384
# 04/2022                               62
# 06/2021                               47
# 03/2021                               39
# 03/2022                               36
#                                    ...
# 06/2021\n,\n121 g CO2/km (comb)        1
# 02/2020\n,\n139 g CO2/km (comb)        1
# 10/2021\n,\n136 g CO2/km (comb)        1
# 06/2019\n,\n139 g CO2/km (comb)        1
# 01/2022\n,\n168 g CO2/km (comb)        1
# Name: next_inspection, Length: 1385, dtype: int64
# #####################

# %%
df[['next_inspection','inspection_new']]
# Out:
#                        next_inspection               inspection_new
# 0       06/2021\n,\n99 g CO2/km (comb)               Yes\n,\nEuro 6
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN  Yes\n,\n109 g CO2/km (comb)
# ...                                ...                          ...
# 15914                              NaN                          NaN
# 15915  01/2022\n,\n168 g CO2/km (comb)                          NaN
# 15916                              NaN         Yes\n,\nEuro 6d-TEMP
# 15917                              NaN                          NaN
# 15918                              NaN  Yes\n,\n153 g CO2/km (comb)
#
# [15919 rows x 2 columns]

# %%
df.next_inspection.str.extract(r"(\d+/\d{0,4})")
# Out:
#              0
# 0      06/2021
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 15914      NaN
# 15915  01/2022
# 15916      NaN
# 15917      NaN
# 15918      NaN
#
# [15919 rows x 1 columns]

# %%
df['next_inspection_date']= df.next_inspection.str.extract(r"(\d+/\d{0,4})")

# %% [markdown]
# # inspection_new

# %%
df.inspection_new
# Out:
# 0                     Yes\n,\nEuro 6
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4        Yes\n,\n109 g CO2/km (comb)
#                     ...
# 15914                            NaN
# 15915                            NaN
# 15916           Yes\n,\nEuro 6d-TEMP
# 15917                            NaN
# 15918    Yes\n,\n153 g CO2/km (comb)
# Name: inspection_new, Length: 15919, dtype: object

# %%
df.inspection_new.value_counts()
# Out:
# Yes\n,\nEuro 6                                                                   523
# Yes                                                                              442
# Yes\n,\n102 g CO2/km (comb)                                                      174
# Yes\n,\n4 (Green)                                                                166
# Yes\n,\nEuro 6d-TEMP                                                             134
# Yes\n,\n97 g CO2/km (comb)                                                        89
# Yes\n,\n0 kWh/100 km (comb)                                                       86
# Yes\n,\n119 g CO2/km (comb)                                                       84
# Yes\n,\n128 g CO2/km (comb)                                                       81
# Yes\n,\n104 g CO2/km (comb)                                                       76
# Yes\n,\n95 g CO2/km (comb)                                                        58
# ...

# %%
df.inspection_new.str.split('\n').str[0]
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        Yes
#         ...
# 15914    NaN
# 15915    NaN
# 15916    Yes
# 15917    NaN
# 15918    Yes
# Name: inspection_new, Length: 15919, dtype: object

# %%
df['insp_new']=df.inspection_new.str.split('\n').str[0]

# %% [markdown]
# # Warranty

# %%
df.warranty
# Out:
# 0                 4 (Green)
# 1                       NaN
# 2        99 g CO2/km (comb)
# 3                       NaN
# 4                    Euro 6
#                 ...
# 15914             24 months
# 15915                Euro 6
# 15916             4 (Green)
# 15917                   NaN
# 15918                   NaN
# Name: warranty, Length: 15919, dtype: object

# %%
first_look('warranty')
# Out:
# column name :  warranty
# --------------------------------
# Per_of_Nulls   :  % 42.48
# Num_of_Nulls   :  6763
# Num_of_Uniques :  505
#
# NaN                                                                                    6763
# Euro 6                                                                                 1868
# 12 months                                                                              1305
# 24 months                                                                               585
# 4 (Green)                                                                               517
# 12 months\n,\nEuro 6                                                                    425
# Euro 6d-TEMP                                                                            362
# 48 months                                                                               112
# 120 g CO2/km (comb)                                                                      93
# ...

# %%
df.warranty.str.contains('Year', case=False).sum()
# Out:
# 0

# %%
df.warranty.str.contains('month', case=False).sum()
# Out:
# 4853

# %%
df.warranty.str.extract(r"(\d+)\s*month") #\s bosluk birakiyor manuel de koayabilirsin
#* zero or more demek
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 15914   24
# 15915  NaN
# 15916  NaN
# 15917  NaN
# 15918  NaN
#
# [15919 rows x 1 columns]

# %%
df.warranty.str.extract(r"(\d+)\s*month").isna().sum()
# Out:
# 0    11066
# dtype: int64

# %%
df['warranty_month'] = df.warranty.str.extract(r"(\d+)\s*month")

# %% [markdown]
# # full_service

# %%
df.full_service
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3        99 g CO2/km (comb)
# 4                 4 (Green)
#                 ...
# 15914                   NaN
# 15915                   NaN
# 15916                   NaN
# 15917                   NaN
# 15918                   NaN
# Name: full_service, Length: 15919, dtype: object

# %%
first_look('full_service')
# Out:
# column name :  full_service
# --------------------------------
# Per_of_Nulls   :  % 60.86
# Num_of_Nulls   :  9689
# Num_of_Uniques :  120
#
# NaN                                                                     9689
# 4 (Green)                                                               2235
# Euro 6                                                                  2097
# Euro 6d-TEMP                                                             399
# 120 g CO2/km (comb)                                                      105
# 126 g CO2/km (comb)                                                       84
# 104 g CO2/km (comb)                                                       77
# 97 g CO2/km (comb)                                                        76
# 124 g CO2/km (comb)                                                       61
# 99 g CO2/km (comb)                                                        60
# ...

# %%
df['full_service'].nunique()
# Out:
# 120

# %%
#df.drop(columns='full_service', inplace=True)

# %%
df.shape
# Out:
# (15919, 49)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'offer_number', 'first_registration',
#        'body_color', 'paint_type', 'body_color_original', 'upholstery',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type',
#        'displacement', 'cylinders', 'weight', 'drive_chain', 'fuel',
#        'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'cons_comb', 'cons_city', 'cons_country', 'hp_kW',
#        'next_inspection_date', 'insp_new', 'warranty_month'],
#       dtype='object')

# %% [markdown]
# # Non_smoking_vehicle

# %%
first_look('non_smoking_vehicle')
# Out:
# column name :  non_smoking_vehicle
# --------------------------------
# Per_of_Nulls   :  % 78.26
# Num_of_Nulls   :  12459
# Num_of_Uniques :  92
#
# NaN                                                                     12459
# 4 (Green)                                                                1240
# Euro 6                                                                   1127
# Euro 6d-TEMP                                                              345
# 120 g CO2/km (comb)                                                        63
# 85 g CO2/km (comb)                                                         46
# 107 g CO2/km (comb)                                                        36
# 104 g CO2/km (comb)                                                        36
# 153 g CO2/km (comb)                                                        31
# 124 g CO2/km (comb)                                                        29
# ...

# %%
#it may help to fill the missing values for other columns later.

# %% [markdown]
# # offer_number

# %%
first_look('offer_number')
# Out:
# column name :  offer_number
# --------------------------------
# Per_of_Nulls   :  % 19.94
# Num_of_Nulls   :  3175
# Num_of_Uniques :  11440
#
# NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
# #####################

# %%
first_look('offer_number')
# Out:
# column name :  offer_number
# --------------------------------
# Per_of_Nulls   :  % 19.94
# Num_of_Nulls   :  3175
# Num_of_Uniques :  11440
#
# NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
# #####################

# %% [markdown]
# ## body_color

# %%
#Check the null values later

# %% [markdown]
# ## paint_type column

# %%
first_look('paint_type')
# Out:
# column name :  paint_type
# --------------------------------
# Per_of_Nulls   :  % 36.26
# Num_of_Nulls   :  5772
# Num_of_Uniques :  3
#
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
# #####################

# %%
#check the null values later

# %% [markdown]
# ## body_color_orginal

# %%
first_look('body_color_original')
# Out:
# column name :  body_color_original
# --------------------------------
# Per_of_Nulls   :  % 23.61
# Num_of_Nulls   :  3759
# Num_of_Uniques :  1915
#
# NaN                              3759
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            240
# Brillantschwarz                   216
#                                  ...
# GRIS NANO                           1
# Tiefsee-blau                        1
# LAVAROT                             1
# BLU COSMO                           1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1916, dtype: int64
# #####################

# %%
df[['body_color','body_color_original', 'paint_type']]
# Out:
#       body_color     body_color_original paint_type
# 0          Black           Mythosschwarz   Metallic
# 1            Red                     NaN        NaN
# 2          Black  mythosschwarz metallic   Metallic
# 3          Brown                     NaN   Metallic
# 4          Black  Mythosschwarz Metallic   Metallic
# ...          ...                     ...        ...
# 15914       Grey            Grigio scuro   Metallic
# 15915       Grey     Stahl-Grau Metallic   Metallic
# 15916      White             arktis-weiß        NaN
# 15917       Grey                  Grigio        NaN
# 15918       Grey  Titanium-Grau Metallic   Metallic
#
# [15919 rows x 3 columns]

# %%
df.shape
# Out:
# (15919, 49)

# %% [markdown]
# # upholstery

# %%
first_look('upholstery')
# Out:
# column name :  upholstery
# --------------------------------
# Per_of_Nulls   :  % 23.37
# Num_of_Nulls   :  3720
# Num_of_Uniques :  46
#
# Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# ...

# %%
df.upholstery
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: upholstery, Length: 15919, dtype: object

# %%
df.upholstery.str.extract("(.+),(.+)")
# Out:
#                   0       1
# 0             Cloth   Black
# 1             Cloth    Grey
# 2             Cloth   Black
# 3               NaN     NaN
# 4             Cloth   Black
# ...             ...     ...
# 15914           NaN     NaN
# 15915           NaN     NaN
# 15916  Full leather   Black
# 15917           NaN     NaN
# 15918  Full leather   Brown
#
# [15919 rows x 2 columns]

# %%
df.upholstery.str.extract("(.+),(.+)")[0].unique()
# Out:
# array(['Cloth', nan, 'Part leather', 'Full leather', 'Other', 'alcantara',
#        'Velour'], dtype=object)

# %%
df.upholstery.str.extract("(.+),(.+)")[1].unique()
# Out:
# array([' Black', ' Grey', nan, ' Other', ' White', ' Red', ' Blue',
#        ' Orange', ' Brown', ' Beige', ' Yellow'], dtype=object)

# %%
type_=['Cloth', 'Part leather', 'Full leather', 'Other', 'alcantara',
       'Velour']
color_ = ['Black', 'Grey', 'White', 'Red', 'Blue', 'Orange',
       'Brown', 'Beige', 'Yellow']

# %%
df.upholstery.str.split(', ').str[0]
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: upholstery, Length: 15919, dtype: object

# %%
a_type = df.upholstery.str.split(', ').str[0]
a_type
# Out:
# 0               Cloth
# 1               Cloth
# 2               Cloth
# 3                 NaN
# 4               Cloth
#              ...
# 15914             NaN
# 15915           Cloth
# 15916    Full leather
# 15917    Part leather
# 15918    Full leather
# Name: upholstery, Length: 15919, dtype: object

# %%
a_type.value_counts()
# Out:
# Cloth           8423
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# Blue               2
# White              2
# Name: upholstery, dtype: int64

# %%
a_type[a_type.isin(color_)]
# Out:
# 29       Black
# 64       Black
# 112      Black
# 180       Grey
# 194       Blue
# 278      Black
# 330      Black
# 381      Black
# 446      Black
# 460      Black
# 491      Black
# 524      Black
# 569      Black
# 577      Black
# 639      Black
# 646      Black
# 667      Black
# 688      Black
# 735      Black
# 764      Black
# 813      Black
# 934      Black
# 989      Black
# 1077     Black
# 1167     Black
# 1192     Black
# 1294     Black
# 1368      Grey
# 1395     Black
# 1398     Black
# 1425     Black
# 1469     Black
# 1517     Black
# 1600      Grey
# 1667     Black
# 1673     Black
# 1682     Black
# 1770     Black
# 1772     Black
# 1773     Black
# 1799     Black
# 1818     Black
# 1876     Black
# 1886      Grey
# 1888      Grey
# 1974     Black
# 2382     Black
# 2422     Black
# 2589     Black
# 2617      Grey
# 2622      Grey
# 2624     Black
# 2627      Grey
# 2630      Grey
# 2647      Grey
# 2648      Grey
# 2649      Grey
# 2650      Grey
# ...

# %%
a_color = a_type[a_type.isin(color_)]
a_color
# Out:
# 29       Black
# 64       Black
# 112      Black
# 180       Grey
# 194       Blue
# 278      Black
# 330      Black
# 381      Black
# 446      Black
# 460      Black
# 491      Black
# 524      Black
# 569      Black
# 577      Black
# 639      Black
# 646      Black
# 667      Black
# 688      Black
# 735      Black
# 764      Black
# 813      Black
# 934      Black
# 989      Black
# 1077     Black
# 1167     Black
# 1192     Black
# 1294     Black
# 1368      Grey
# 1395     Black
# 1398     Black
# 1425     Black
# 1469     Black
# 1517     Black
# 1600      Grey
# 1667     Black
# 1673     Black
# 1682     Black
# 1770     Black
# 1772     Black
# 1773     Black
# 1799     Black
# 1818     Black
# 1876     Black
# 1886      Grey
# 1888      Grey
# 1974     Black
# 2382     Black
# 2422     Black
# 2589     Black
# 2617      Grey
# 2622      Grey
# 2624     Black
# 2627      Grey
# 2630      Grey
# 2647      Grey
# 2648      Grey
# 2649      Grey
# 2650      Grey
# ...

# %%
b_color = df.upholstery.str.split(', ').str[1]
b_color.value_counts()
# Out:
# Black     7710
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery, dtype: int64

# %%
b_color.fillna(a_color, inplace=True)#.value_counts(dropna=False)

# %%
a_type[a_type.isin(color_)] = np.nan

# %%
df['upholstery_type'] =a_type

# %%
df['upholstery_color'] =b_color

# %%
df[['upholstery','upholstery_type','upholstery_color']].head(30)
# Out:
#              upholstery upholstery_type upholstery_color
# 0          Cloth, Black           Cloth            Black
# 1           Cloth, Grey           Cloth             Grey
# 2          Cloth, Black           Cloth            Black
# 3                   NaN             NaN              NaN
# 4          Cloth, Black           Cloth            Black
# 5   Part leather, Black    Part leather            Black
# 6   Part leather, Black    Part leather            Black
# 7          Cloth, Black           Cloth            Black
# 8           Cloth, Grey           Cloth             Grey
# 9                   NaN             NaN              NaN
# 10         Cloth, Black           Cloth            Black
# 11         Cloth, Black           Cloth            Black
# 12  Part leather, Black    Part leather            Black
# 13                  NaN             NaN              NaN
# 14         Cloth, Black           Cloth            Black
# ...

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'offer_number', 'first_registration',
#        'body_color', 'paint_type', 'body_color_original', 'upholstery',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type',
#        'displacement', 'cylinders', 'weight', 'drive_chain', 'fuel',
#        'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version', 'cons_comb', 'cons_city', 'cons_country', 'hp_kW',
#        'next_inspection_date', 'insp_new', 'warranty_month', 'upholstery_type',
#        'upholstery_color'],
#       dtype='object')

# %% [markdown]
# ## nr_of_doors

# %%
first_look('nr_of_doors')
# Out:
# column name :  nr_of_doors
# --------------------------------
# Per_of_Nulls   :  % 1.33
# Num_of_Nulls   :  212
# Num_of_Uniques :  6
#
# 5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
# #####################

# %%
df['nr_of_doors'] = df['nr_of_doors'].astype('float')

# %% [markdown]
# ## nr_of_seats

# %%
first_look('nr_of_seats')
# Out:
# column name :  nr_of_seats
# --------------------------------
# Per_of_Nulls   :  % 6.14
# Num_of_Nulls   :  977
# Num_of_Uniques :  6
#
# 5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
# #####################

# %%
df['nr_of_seats'] = df['nr_of_seats'].astype('float')

# %% [markdown]
# ## model_code

# %%
first_look('model_code')
# Out:
# column name :  model_code
# --------------------------------
# Per_of_Nulls   :  % 68.73
# Num_of_Nulls   :  10941
# Num_of_Uniques :  232
#
# NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
# 0588/BDF      175
# 1844/ADJ      175
# 0588/BCV      139
# 3333/BAJ      122
# 3333/BEF      118
# 0588/AYB      117
# 0035/BEL      111
# 0588/BLL      109
# 3333/BHJ       87
# 0588/BLH       86
# 0035/BKN       84
# 0035/BFM       84
# 0588/AWJ       82
# 3333/BJR       79
# 0588/BHM       79
# 0035/BFI       76
# 0035/BKQ       69
# 0588/BDC       67
# 0035/BKU       62
# 0035/BHM       60
# 3333/BDQ       59
# 0035/BBZ       59
# 0588/BNN       58
# 0588/BLG       53
# 0588/BDG       52
# 3333/BEG       50
# 0035/BHQ       48
# 0035/BCJ       46
# 0035/BFP       44
# 0035/BHP       43
# 1844/AJG       43
# 0035/BHY       41
# 0588/BHL       40
# 0035/BFJ       39
# 0035/BCL       38
# 0588/BCZ       35
# 1844/ACW       35
# ...

# %% [markdown]
# ## gearing_type

# %%
first_look('gearing_type')
# Out:
# column name :  gearing_type
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  3
#
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# #####################

# %% [markdown]
# ## displacement

# %%
first_look('displacement')
# Out:
# column name :  displacement
# --------------------------------
# Per_of_Nulls   :  % 3.12
# Num_of_Nulls   :  496
# Num_of_Uniques :  77
#
# 1,598 cc     4761
# 999 cc       2438
# 1,398 cc     1314
# 1,399 cc      749
# 1,229 cc      677
# 1,956 cc      670
# 1,461 cc      595
# 1,490 cc      559
# NaN           496
# 1,422 cc      467
# 1,197 cc      353
# 898 cc        351
# 1,395 cc      320
# 1,968 cc      301
# 1,149 cc      288
# 1,618 cc      212
# 1,798 cc      210
# 1,498 cc      196
# 1,600 cc      130
# 1,248 cc      110
# 1,997 cc      103
# 1,364 cc      102
# 1,400 cc       90
# 998 cc         72
# 1,500 cc       50
# 2,000 cc       46
# 1,000 cc       40
# 1 cc           36
# 1,998 cc       25
# 2,480 cc       20
# 1,200 cc       18
# 1,984 cc       18
# 1,397 cc       11
# 899 cc         11
# 160 cc          6
# 929 cc          5
# 1,499 cc        5
# 997 cc          4
# 1,596 cc        4
# 139 cc          4
# 900 cc          4
# 1,599 cc        3
# ...

# %%
df.displacement.str.replace(',','').str.extract(r'(\d+)')
# Out:
#           0
# 0      1422
# 1      1798
# 2      1598
# 3      1422
# 4      1422
# ...     ...
# 15914  1997
# 15915  1798
# 15916  1997
# 15917  1997
# 15918  1798
#
# [15919 rows x 1 columns]

# %%
df['displacement_cc']=df.displacement.str.replace(',','').str.extract(r'(\d+)').astype('float')

# %%
df.drop('displacement', axis=1, inplace=True)

# %% [markdown]
# ## cylinders

# %%
first_look('cylinders')
# Out:
# column name :  cylinders
# --------------------------------
# Per_of_Nulls   :  % 35.68
# Num_of_Nulls   :  5680
# Num_of_Uniques :  7
#
# 4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64
# #####################

# %%
df['cylinders'] = df.cylinders.astype('float')

# %% [markdown]
# ## weight

# %%
first_look('weight')
# Out:
# column name :  weight
# --------------------------------
# Per_of_Nulls   :  % 43.81
# Num_of_Nulls   :  6974
# Num_of_Uniques :  434
#
# NaN         6974
# 1,163 kg     574
# 1,360 kg     356
# 1,165 kg     301
# 1,335 kg     242
# 1,135 kg     213
# 1,199 kg     205
# 1,734 kg     170
# 1,180 kg     168
# 1,503 kg     165
# 1,350 kg     155
# 1,355 kg     135
# 1,260 kg     127
# 1,275 kg     112
# 1,278 kg     110
# 1,487 kg     109
# 1,425 kg     109
# 1,255 kg     108
# 1,200 kg     107
# 1,522 kg     103
# 1,273 kg     103
# 1,280 kg     102
# 1,403 kg      91
# 1,120 kg      90
# 1,659 kg      89
# 1,195 kg      89
# 1,701 kg      87
# 1,250 kg      84
# 1,441 kg      82
# 1,308 kg      80
# 1,285 kg      80
# 1,613 kg      75
# 1,110 kg      75
# 1,279 kg      72
# 1,364 kg      70
# 1,345 kg      67
# 1,733 kg      65
# 1,325 kg      64
# 1,141 kg      64
# 1,685 kg      64
# 1,071 kg      64
# 1,230 kg      63
# 1,845 kg      56
# 1,090 kg      54
# 1,052 kg      53
# ...

# %%
df['weight_kg']=df.weight.str.replace(',', "").str.extract(r"(\d+)").astype('float')

# %%
df.drop('weight', axis=1, inplace=True)

# %%
df.weight_kg.isnull().sum()
# Out:
# 6974

# %% [markdown]
# ## drive_chain

# %%
first_look('drive_chain')
# Out:
# column name :  drive_chain
# --------------------------------
# Per_of_Nulls   :  % 43.08
# Num_of_Nulls   :  6858
# Num_of_Uniques :  3
#
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64
# #####################

# %%
#check null values later

# %% [markdown]
# ## fuel

# %%
first_look('fuel')
# Out:
# column name :  fuel
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  77
#
# Diesel (Particulate Filter)                                                                                                       4315
# Super 95                                                                                                                          3338
# Gasoline                                                                                                                          3175
# Diesel                                                                                                                            2984
# Super 95 / Regular/Benzine 91                                                                                                      424
# Regular/Benzine 91                                                                                                                 354
# ...

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/]['''):
    """
    exclude  - satırlar da kategori ayırım yerleri
    pattern  - satırdaki veriyi ayırma regex
    strip    - alakasız işaretleri kaldırma
    """
    import re
    column = Series.dropna().apply(str).str.strip(strip)
    diff_value = list()
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
get_diff_category_column(df['fuel'])
# Out:
# {0: 'Biodiesel',
#  1: 'Biogas',
#  2: 'CNG',
#  3: 'CNG (Particulate Filter)',
#  4: 'Diesel',
#  5: 'Diesel (Particulate Filter)',
#  6: 'Domestic gas H',
#  7: 'Electric',
#  8: 'Electric/Gasoline',
#  9: 'Gasoline',
#  10: 'Gasoline (Particulate Filter)',
#  11: 'LPG',
#  12: 'Liquid petroleum gas (LPG)',
#  13: 'Others',
#  14: 'Others (Particulate Filter)',
#  15: 'Regular/Benzine 91',
#  16: 'Regular/Benzine 91 (Particulate Filter)',
#  17: 'Regular/Benzine E10 91',
#  18: 'Regular/Benzine E10 91 (Particulate Filter)',
#  19: 'Super 95',
#  20: 'Super 95 (Particulate Filter)',
#  21: 'Super E10 95',
#  22: 'Super E10 95 (Particulate Filter)',
#  23: 'Super Plus 98',
#  24: 'Super Plus 98 (Particulate Filter)',
#  25: 'Super Plus E10 98',
#  26: 'Super Plus E10 98 (Particulate Filter)'}

# %%
benzine = ["Gasoline", "Regular", "Others", "Super"]
diesel  = ["Biodiesel", "Diesel"]
lpg     = ["Biogas", "CNG", "Domestic gas H", "LPG"]
hybrit  = ['Electric', 'Electric/Gasoline']

def fueltype(x):
    if any(i in x for i in hybrit):
        return "Hybrit"
    elif any(i in x for i in lpg):
        return "LPG/CNG"
    elif any(i in x for i in benzine):
        return "Benzine"
    elif any(i in x for i in diesel):
        return "Diesel"
    else:
        return x

# %%
df["fuel"].apply(fueltype).value_counts()
# Out:
# Benzine    8551
# Diesel     7299
# LPG/CNG      64
# Hybrit        5
# Name: fuel, dtype: int64

# %%
df["fuel"] = df["fuel"].apply(fueltype)

# %% [markdown]
# ## consumption

# %%
first_look('consumption')
# Out:
# column name :  consumption
# --------------------------------
# Per_of_Nulls   :  % 11.97
# Num_of_Nulls   :  1906
# Num_of_Uniques :  875
#
# NaN                                                                           1906
# 3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.7 l/100 km (country)         304
# 4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)           276
# 5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)         257
# 3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)         253
# 4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)         244
# 4.5 l/100 km (comb)'],['5.7 l/100 km (city)'],['3.8 l/100 km (country)         214
# 4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)         213
# 3.3 l/100 km (comb)'],['3.5 l/100 km (city)'],['3.1 l/100 km (country)         210
# 4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)           201
# ...

# %%
#already done at the above

# %%
df.drop('consumption', axis=1, inplace=True)

# %% [markdown]
# ## co_2_emission'

# %%
first_look('co_2_emission')
# Out:
# column name :  co_2_emission
# --------------------------------
# Per_of_Nulls   :  % 15.3
# Num_of_Nulls   :  2436
# Num_of_Uniques :  122
#
# NaN                       2436
# 120 g CO2/km (comb)        740
# 99 g CO2/km (comb)         545
# 97 g CO2/km (comb)         537
# 104 g CO2/km (comb)        501
# 102 g CO2/km (comb)        477
# 103 g CO2/km (comb)        445
# 114 g CO2/km (comb)        382
# 124 g CO2/km (comb)        372
# 107 g CO2/km (comb)        362
# 108 g CO2/km (comb)        362
# 119 g CO2/km (comb)        361
# 106 g CO2/km (comb)        349
# 128 g CO2/km (comb)        329
# 126 g CO2/km (comb)        282
# 85 g CO2/km (comb)         275
# 118 g CO2/km (comb)        270
# 110 g CO2/km (comb)        266
# 127 g CO2/km (comb)        257
# 117 g CO2/km (comb)        254
# 111 g CO2/km (comb)        237
# 113 g CO2/km (comb)        235
# 109 g CO2/km (comb)        234
# 139 g CO2/km (comb)        224
# 140 g CO2/km (comb)        218
# ...

# %%
df['co_2_emission'].value_counts(dropna=False)
# Out:
# NaN                       2436
# 120 g CO2/km (comb)        740
# 99 g CO2/km (comb)         545
# 97 g CO2/km (comb)         537
# 104 g CO2/km (comb)        501
# 102 g CO2/km (comb)        477
# 103 g CO2/km (comb)        445
# 114 g CO2/km (comb)        382
# 124 g CO2/km (comb)        372
# 107 g CO2/km (comb)        362
# 108 g CO2/km (comb)        362
# 119 g CO2/km (comb)        361
# 106 g CO2/km (comb)        349
# 128 g CO2/km (comb)        329
# 126 g CO2/km (comb)        282
# 85 g CO2/km (comb)         275
# 118 g CO2/km (comb)        270
# 110 g CO2/km (comb)        266
# 127 g CO2/km (comb)        257
# 117 g CO2/km (comb)        254
# 111 g CO2/km (comb)        237
# 113 g CO2/km (comb)        235
# 109 g CO2/km (comb)        234
# 139 g CO2/km (comb)        224
# 140 g CO2/km (comb)        218
# 129 g CO2/km (comb)        213
# 105 g CO2/km (comb)        202
# 135 g CO2/km (comb)        202
# 92 g CO2/km (comb)         198
# 130 g CO2/km (comb)        180
# ...

# %%
df['co_2_emission'] = df['co_2_emission'].str.replace(',', '').str.extract('(\d+)').astype(float)

# %% [markdown]
# ## emission_class

# %%
first_look('emission_class')
# Out:
# column name :  emission_class
# --------------------------------
# Per_of_Nulls   :  % 22.79
# Num_of_Nulls   :  3628
# Num_of_Uniques :  6
#
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64
# #####################

# %%
df['emission_class'].value_counts(dropna=False)
# Out:
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64

# %% [markdown]
# ## comfort_&_convenience

# %%
first_look('comfort_&_convenience')
# Out:
# column name :  comfort_&_convenience
# --------------------------------
# Per_of_Nulls   :  % 5.78
# Num_of_Nulls   :  920
# Num_of_Uniques :  6198
#
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# ...

# %%
df['comfort_&_convenience'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   216
# ...

# %%
get_diff_category_column(df['comfort_&_convenience'])
# Out:
# {0: 'Air conditioning',
#  1: 'Air suspension',
#  2: 'Armrest',
#  3: 'Automatic climate control',
#  4: 'Auxiliary heating',
#  5: 'Cruise control',
#  6: 'Electric Starter',
#  7: 'Electric tailgate',
#  8: 'Electrical side mirrors',
#  9: 'Electrically adjustable seats',
#  10: 'Electrically heated windshield',
#  11: 'Heads-up display',
#  12: 'Heated steering wheel',
#  13: 'Hill Holder',
#  14: 'Keyless central door lock',
#  15: 'Leather seats',
#  16: 'Leather steering wheel',
#  17: 'Light sensor',
#  18: 'Lumbar support',
#  19: 'Massage seats',
#  20: 'Multi-function steering wheel',
#  21: 'Navigation system',
#  22: 'Panorama roof',
#  23: 'Park Distance Control',
#  24: 'Parking assist system camera',
#  25: 'Parking assist system self-steering',
#  26: 'Parking assist system sensors front',
#  27: 'Parking assist system sensors rear',
#  28: 'Power windows',
#  29: 'Rain sensor',
#  30: 'Seat heating',
#  31: 'Seat ventilation',
#  32: 'Split rear seats',
# ...

# %%
df.rename(columns={'comfort_&_convenience':'comfort_convenience'}, inplace=True)

# %% [markdown]
# ## entertainment_&_media

# %%
first_look('entertainment_&_media')
# Out:
# column name :  entertainment_&_media
# --------------------------------
# Per_of_Nulls   :  % 8.63
# Num_of_Nulls   :  1374
# Num_of_Uniques :  346
#
# NaN                                                                                                               1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                                        1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                                     982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                                           783
# On-board computer,Radio                                                                                            487
# Radio                                                                                                              477
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,USB                                               465
# ...

# %%
df['entertainment_&_media'].value_counts(dropna=False)
# Out:
# NaN                                                                                                               1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                                        1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                                     982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                                           783
# On-board computer,Radio                                                                                            487
# Radio                                                                                                              477
# Bluetooth,CD player,Hands-free equipment,On-board computer,Radio,USB                                               465
# On-board computer                                                                                                  461
# ...

# %%
get_diff_category_column(df['entertainment_&_media'])
# Out:
# {0: 'Bluetooth',
#  1: 'CD player',
#  2: 'Digital radio',
#  3: 'Hands-free equipment',
#  4: 'MP3',
#  5: 'On-board computer',
#  6: 'Radio',
#  7: 'Sound system',
#  8: 'Television',
#  9: 'USB'}

# %%
df.rename(columns={'entertainment_&_media':'entertainment_media'}, inplace=True)

# %% [markdown]
# ## extras

# %%
first_look('extras')
# Out:
# column name :  extras
# --------------------------------
# Per_of_Nulls   :  % 18.61
# Num_of_Nulls   :  2962
# Num_of_Uniques :  659
#
# Alloy wheels                                                                                                                                   3245
# NaN                                                                                                                                            2962
# Alloy wheels,Touch screen                                                                                                                       697
# Alloy wheels,Voice Control                                                                                                                      577
# Alloy wheels,Touch screen,Voice Control                                                                                                         541
# ...

# %%
df['extras'].value_counts(dropna=False)
# Out:
# Alloy wheels                                                                                                                                   3245
# NaN                                                                                                                                            2962
# Alloy wheels,Touch screen                                                                                                                       697
# Alloy wheels,Voice Control                                                                                                                      577
# Alloy wheels,Touch screen,Voice Control                                                                                                         541
# Alloy wheels,Roof rack                                                                                                                          385
# ...

# %%
get_diff_category_column(df['extras'])
# Out:
# {0: 'Alloy wheels',
#  1: 'Cab or rented Car',
#  2: 'Catalytic Converter',
#  3: 'Handicapped enabled',
#  4: 'Right hand drive',
#  5: 'Roof rack',
#  6: 'Shift paddles',
#  7: 'Ski bag',
#  8: 'Sliding door',
#  9: 'Sport package',
#  10: 'Sport seats',
#  11: 'Sport suspension',
#  12: 'Touch screen',
#  13: 'Trailer hitch',
#  14: 'Tuned car',
#  15: 'Voice Control',
#  16: 'Winter tyres'}

# %% [markdown]
# ## safety_&_security

# %%
first_look('safety_&_security')
# Out:
# column name :  safety_&_security
# --------------------------------
# Per_of_Nulls   :  % 6.17
# Num_of_Nulls   :  982
# Num_of_Uniques :  4443
#
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ...

# %%
get_diff_category_column(df['safety_&_security'])
# Out:
# {0: 'ABS',
#  1: 'Adaptive Cruise Control',
#  2: 'Adaptive headlights',
#  3: 'Alarm system',
#  4: 'Blind spot monitor',
#  5: 'Central door lock',
#  6: 'Central door lock with remote control',
#  7: 'Daytime running lights',
#  8: 'Driver drowsiness detection',
#  9: 'Driver-side airbag',
#  10: 'Electronic stability control',
#  11: 'Emergency brake assistant',
#  12: 'Emergency system',
#  13: 'Fog lights',
#  14: 'Head airbag',
#  15: 'Immobilizer',
#  16: 'Isofix',
#  17: 'LED Daytime Running Lights',
#  18: 'LED Headlights',
#  19: 'Lane departure warning system',
#  20: 'Night view assist',
#  21: 'Passenger-side airbag',
#  22: 'Power steering',
#  23: 'Rear airbag',
#  24: 'Side airbag',
#  25: 'Tire pressure monitoring system',
#  26: 'Traction control',
#  27: 'Traffic sign recognition',
#  28: 'Xenon headlights'}

# %%
df.rename(columns={'safety_&_security':'safety_security'}, inplace=True)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'offer_number', 'first_registration',
#        'body_color', 'paint_type', 'body_color_original', 'upholstery',
#        'nr_of_doors', 'nr_of_seats', 'model_code', 'gearing_type', 'cylinders',
#        'drive_chain', 'fuel', 'co_2_emission', 'emission_class',
#        'comfort_convenience', 'entertainment_media', 'extras',
#        'safety_security', 'description', 'emission_label', 'gears',
#        'country_version', 'cons_comb', 'cons_city', 'cons_country', 'hp_kW',
#        'next_inspection_date', 'insp_new', 'warranty_month', 'upholstery_type',
#        'upholstery_color', 'displacement_cc', 'weight_kg'],
#       dtype='object')

# %% [markdown]
# ## description

# %%
df['description'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %% [markdown]
# ## emission_label

# %%
first_look('emission_label')
# Out:
# column name :  emission_label
# --------------------------------
# Per_of_Nulls   :  % 75.22
# Num_of_Nulls   :  11974
# Num_of_Uniques :  5
#
# NaN               11974
# 4 (Green)          3553
# 1 (No sticker)      381
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
# #####################

# %%
df['emission_label'].value_counts(dropna=False)
# Out:
# NaN               11974
# 4 (Green)          3553
# 1 (No sticker)      381
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64

# %% [markdown]
# ## gears

# %%
first_look('gears')
# Out:
# column name :  gears
# --------------------------------
# Per_of_Nulls   :  % 29.6
# Num_of_Nulls   :  4712
# Num_of_Uniques :  10
#
# 6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
# #####################

# %%
df['gears'].value_counts(dropna=False)
# Out:
# 6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64

# %%
df['gears'] = df['gears'].astype(float)

# %% [markdown]
# ## country_version

# %%
df['country_version'].value_counts(dropna=False)
# Out:
# NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64

# %%
#Done for the cleaning at first look and dig in more

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   make_model            15919 non-null  object
#  1   short_description     15870 non-null  object
#  2   body_type             15859 non-null  object
#  3   price                 15919 non-null  int64
#  4   vat                   11406 non-null  object
#  5   km                    14895 non-null  float64
#  6   registration          14322 non-null  datetime64[ns]
#  7   prev_owner            9091 non-null   float64
#  8   hp                    15919 non-null  object
#  9   type                  15917 non-null  object
#  10  previous_owners       9279 non-null   object
#  11  next_inspection       3535 non-null   object
#  12  inspection_new        3932 non-null   object
#  13  warranty              9156 non-null   object
# ...

# %%
# "url" tüm analiz sonrası silinecek veya analiz başında silinecek df_orjinal den bakılacak
# Audi A2 ile ilgili tek satır veri var
# km sütunu temizlenecek ve integer yapılacak
# registration sutununda "-/-" şeklinde veri var
# prev_owner sutunu temizlecek ve integer yapılacak
# hp sutunu temizlenecek integer yapılacak ve "- kW,1 kW" bu gibi küçük değerlere bakılacak
# previous_owners kolonunun içeriği ve adı kıyaslanacak. temizlenecek integer yapılacak
            #ve prev_owner sutunu ile kıyaslanıp tek sutun yapılacak
# next_inspection null veriler doldurulabilir.temizlenecek. datatype date yapılacak
# inspection_new kolonu "yes" "no" şeklinde düzenlenebilir.
# warranty kolonunda null ve boş veriler var. ay formatına çevirilecek ve integer yapılacak
# full_service kolonunda null ve boş veriler var.
# non_smoking_vehicle kolonunda null ve boş veriler var.
# make_model kolonu ile "make" ve "model" kolonları karşılaştırılıp hangisinin düşürüleceğine karar verilecek
# offer number kolonu ML de işe yaramayabilir. düşülebilir.
# first_registration kolonundaki null değerler için registration kolonuna bakılabilir..
# paint_type kolonu metallic, non-metallic ve other olarak kategorize edilebilir
# upholstery kolonu kategorize edilecek
# body ve body type sutunu aynı birisi düşürülecek
# "nr_of_doors" kolonunda "1,7 veya null" veriler incelenecek
# "nr_of_seats" kolonunda "3,6 veya null" veriler incelenecek
# model_code kolonu düşürülebilir
# displacement kolonu numeric yapılacak
# cylinders kolonundaki null verilerkontrol edilecek
# weight kolonu numeric yapılacak
#drive chain kolonu null degerler doldurulacak
#fuel kolonu kategorize edilecek(benzin, dizel, gaz, diger olabilir)
#consumption kolonu 3 column e bolundu, null degerleri check et
#emission class andco2 emission a bak birlesebilir

#comfort_&_convenience null degerler incelenecek.
#entertainment&media 















# "url" tüm analiz sonrası silinecek veya analiz başında silinecek df_orjinal den bakılacak
# Audi A2 ile ilgili tek satır veri var
# km sütunu temizlenecek ve integer yapılacak
# registration sutununda "-/-" şeklinde veri var
# prev_owner sutunu temizlecek ve integer yapılacak
# hp sutunu temizlenecek integer yapılacak ve "- kW,1 kW" bu gibi küçük değerlere bakılacak
# previous_owners kolonunun içeriği ve adı kıyaslanacak. temizlenecek integer yapılacak 
            #ve prev_owner sutunu ile kıyaslanıp tek sutun yapılacak
# next_inspection null veriler doldurulabilir.temizlenecek. datatype date yapılacak
# inspection_new kolonu "yes" "no" şeklinde düzenlenebilir.
# warranty kolonunda null ve boş veriler var. ay formatına çevirilecek ve integer yapılacak
# full_service kolonunda null ve boş veriler var.
# non_smoking_vehicle kolonunda null ve boş veriler var.
# make_model kolonu ile "make" ve "model" kolonları karşılaştırılıp hangisinin düşürüleceğine karar verilecek

# %% [markdown]
# # Save the file as csv

# %%
df.to_csv('Scout_car_cleaned_s.csv', index=False)

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %%
df = pd.read_csv('Scout_car_cleaned_s.csv')

# %%
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat        km registration  prev_owner      hp  type  \
# 0  15770    VAT deductible 56013.000   2016-01-01       2.000   66 kW  Used
# 1  14500  Price negotiable 80000.000   2017-03-01         NaN  141 kW  Used
# 2  14640    VAT deductible 83450.000   2016-02-01       1.000   85 kW  Used
# 3  14500               NaN 73000.000   2016-08-01       1.000   66 kW  Used
# 4  16790               NaN 16200.000   2016-05-01       1.000   66 kW  Used
#
#   previous_owners                 next_inspection  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   make_model            15919 non-null  object
#  1   short_description     15870 non-null  object
#  2   body_type             15859 non-null  object
#  3   price                 15919 non-null  int64
#  4   vat                   11406 non-null  object
#  5   km                    14895 non-null  float64
#  6   registration          14322 non-null  object
#  7   prev_owner            9091 non-null   float64
#  8   hp                    15919 non-null  object
#  9   type                  15917 non-null  object
#  10  previous_owners       9279 non-null   object
#  11  next_inspection       3535 non-null   object
#  12  inspection_new        3932 non-null   object
#  13  warranty              9156 non-null   object
#  14  full_service          6230 non-null   object
# ...

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
